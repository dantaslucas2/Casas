# %% [markdown]
# ### Caracterização e visualização de dados

# %%
import pandas as pd
import numpy as np
import math
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures,OneHotEncoder
from matplotlib import pyplot as plt
from category_encoders.one_hot import OrdinalEncoder
import category_encoders as ce
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_log_error

# %%
newDataframe = pd.read_csv("test_categorical_variables.csv")

#y = newDataframe['SalePrice']
y = pd.DataFrame(newDataframe['SalePrice'])
X = newDataframe.drop(['SalePrice'], axis=1)

y[["SalePrice"]] = y[["SalePrice"]].apply(np.log)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# ### Validação cruzada

# %%
"""
def f_rmse(y_real, y_pred):
    return mean_squared_error(y_real, y_pred)**0.5

def avalia_classificador(clf, kf, X, y, f_metrica):
    metrica_valid = []
    metrica_train = []
    r2_valid = []
    r2_train = []
    
    y_preds = np.zeros(X.shape[0])
    
    for train, valid in kf.split(X,y):
        x_train = X.iloc[train] 
        y_train = y.iloc[train]
        x_valid = X.iloc[valid] 
        y_valid = y.iloc[valid]
        clf.fit(x_train, y_train) 
        y_pred_train = clf.predict(x_train)
        y_pred_valid = clf.predict(x_valid)
        y_preds[valid] = y_pred_valid[0] 
        
        metrica_valid.append(f_metrica(y_valid, y_pred_valid)) 
        metrica_train.append(f_metrica(y_train, y_pred_train))
        r2_valid.append(r2_score(y_valid, y_pred_valid))
        r2_train.append(r2_score(y_train, y_pred_train))
          
    return y_preds, np.array(metrica_valid).mean(), np.array(metrica_train).mean(), np.array(r2_valid).mean(), np.array(r2_train).mean()
    """
# Out:
# '\ndef f_rmse(y_real, y_pred):\n    return mean_squared_error(y_real, y_pred)**0.5\n\ndef avalia_classificador(clf, kf, X, y, f_metrica):\n    metrica_valid = []\n    metrica_train = []\n    r2_valid = []\n    r2_train = []\n    \n    y_preds = np.zeros(X.shape[0])\n    \n    for train, valid in kf.split(X,y):\n        x_train = X.iloc[train] \n        y_train = y.iloc[train]\n        x_valid = X.iloc[valid] \n        y_valid = y.iloc[valid]\n        clf.fit(x_train, y_train) \n        y_pred_train = clf.predict(x_train)\n        y_pred_valid = clf.predict(x_valid)\n        y_preds[valid] = y_pred_valid[0] \n        \n        metrica_valid.append(f_metrica(y_valid, y_pred_valid)) \n        metrica_train.append(f_metrica(y_train, y_pred_train))\n        r2_valid.append(r2_score(y_valid, y_pred_valid))\n        r2_train.append(r2_score(y_train, y_pred_train))\n          \n    return y_preds, np.array(metrica_valid).mean(), np.array(metrica_train).mean(), np.array(r2_valid).mean(), np.a
# ...

# %% [markdown]
# ### Regressão Linear

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score 
from sklearn.model_selection import KFold

regressor_linear = LinearRegression(fit_intercept = True)

regressor_linear = regressor_linear.fit(X_train, y_train)

y_resposta_treino = regressor_linear.predict(X_train)
y_resposta_teste  = regressor_linear.predict(X_test)

print(' ')
print(' REGRESSOR LINEAR:')
print(' ')
print(' ')
print(' HOLDOUT: ')
print(' ')

print(' Métrica       treino             teste    ')
print(' -------  -----------------  ---------------')

mse_train = mean_squared_error(y_train, y_resposta_treino)
rmse_train = math.sqrt(mse_train)
r2_treino   = r2_score(y_train,y_resposta_treino)

mse_teste = mean_squared_error(y_test, y_resposta_teste)
rmse_teste = math.sqrt(mse_teste)
r2_teste   = r2_score(y_test,y_resposta_teste)

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_train , rmse_teste ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   r2_treino ,   r2_teste ) )

from sklearn.model_selection import cross_val_score

mse_train = cross_val_score(regressor_linear, X_train, y_resposta_treino, scoring='neg_mean_squared_error', cv=5)
rmse_treino = math.sqrt(abs(mse_train.mean()))

mse_test = cross_val_score(regressor_linear, X_test, y_resposta_teste, scoring='neg_mean_squared_error', cv=5)
rmse_test = math.sqrt(abs(mse_test.mean()))

scores_treino = cross_val_score(regressor_linear, X_train, y_resposta_treino, scoring='r2', cv=5)
scores_test = cross_val_score(regressor_linear, X_test, y_resposta_teste, scoring='r2', cv=5)

print(' ')
print(' VALIDAÇÃO CRUZADA :')
print(' ')

print(' Métrica       treino             teste    ')
print(' -------  -----------------  ---------------')

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_treino , rmse_test ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   scores_treino.mean() ,   scores_test.mean() ) )
# Out:
#
#  REGRESSOR LINEAR:
#
#
#  HOLDOUT:
#
#  Métrica       treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0085           0.0097
#       r2             0.9335           0.9301
#
#  VALIDAÇÃO CRUZADA :
#
#  Métrica       treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0061           0.0058
#       r2             0.9646           0.9679

# %% [markdown]
# ### Regressão Logística

# %%
#Não se aplica
y_resposta_treino
# Out:
# array([[2.51632886],
#        [2.49631824],
#        [2.46849257],
#        ...,
#        [2.45608926],
#        [2.48768557],
#        [2.49875414]])

# %% [markdown]
# ### Regressão Bayesiana

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score 
from sklearn.linear_model import BayesianRidge, LinearRegression


bayesian_ridge = BayesianRidge(compute_score=True)

bayesian_ridge = bayesian_ridge.fit(X_train, y_train.values.ravel())

y_resposta_treino = bayesian_ridge.predict(X_train)
y_resposta_teste  = bayesian_ridge.predict(X_test)

print(' ')
print(' REGRESSÃO BAYESIANA:')
print(' ')

print(' ')
print(' HOLDOUT: ')
print(' ')

print(' Métrica        treino             teste    ')
print(' -------  -----------------  ---------------')

mse_treino  = mean_squared_error(y_train,y_resposta_treino)
rmse_treino = math.sqrt(mse_treino)
r2_treino   = r2_score(y_train,y_resposta_treino)

mse_teste  = mean_squared_error(y_test,y_resposta_teste)
rmse_teste = math.sqrt(mse_teste)
r2_teste   = r2_score(y_test,y_resposta_teste)

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_treino , rmse_teste ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   r2_treino ,   r2_teste ) )

from sklearn.model_selection import cross_val_score

mse_train = cross_val_score(bayesian_ridge, X_train, y_resposta_treino, scoring='neg_mean_squared_error', cv=5)
rmse_treino = math.sqrt(abs(mse_train.mean()))

mse_test = cross_val_score(bayesian_ridge, X_test, y_resposta_teste, scoring='neg_mean_squared_error', cv=5)
rmse_test = math.sqrt(abs(mse_test.mean()))

scores_treino = cross_val_score(bayesian_ridge, X_train, y_resposta_treino, scoring='r2', cv=5)
scores_test = cross_val_score(bayesian_ridge, X_test, y_resposta_teste, scoring='r2', cv=5)

print(' ')
print(' VALIDAÇÃO CRUZADA :')
print(' ')

print(' Métrica       treino             teste    ')
print(' -------  -----------------  ---------------')

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_treino , rmse_test ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   scores_treino.mean() ,   scores_test.mean() ) )
# Out:
#
#  REGRESSÃO BAYESIANA:
#
#
#  HOLDOUT:
#
#  Métrica        treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0099           0.0098
#       r2             0.9091           0.9292
#
#  VALIDAÇÃO CRUZADA :
#
#  Métrica       treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0002           0.0028
#       r2             0.9999           0.9924

# %% [markdown]
# ### Árvores de decisão

# %%
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
#from sklearn.metrics import mean_squared_error, r2_score 
from sklearn import metrics
#import math


# Create Decision Tree classifer object
decision_tree_regressor = DecisionTreeRegressor()

# Train Decision Tree Classifer
decision_tree_regressor = decision_tree_regressor.fit(X_train,y_train)

#Predict the response for test dataset
y_resposta_treino = decision_tree_regressor.predict(X_train)
y_resposta_teste = decision_tree_regressor.predict(X_test)

print(' ')
print(' ARVORE DE DECISÃO:')
print(' ')
print(' ')
print(' HOLDOUT: ')
print(' ')

print(' Métrica        treino             teste    ')
print(' -------  -----------------  ---------------')

mse_in  = mean_squared_error(y_train,y_resposta_treino)
rmse_in = math.sqrt(mse_in)
r2_in   = r2_score(y_train,y_resposta_treino)

mse_out  = mean_squared_error(y_test,y_resposta_teste)
rmse_out = math.sqrt(mse_out)
r2_out   = r2_score(y_test,y_resposta_teste)

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_in , rmse_out ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   r2_in ,   r2_out ) )

from sklearn.model_selection import cross_val_score

mse_train = cross_val_score(decision_tree_regressor, X_train, y_resposta_treino, scoring='neg_mean_squared_error', cv=5)
rmse_treino = math.sqrt(abs(mse_train.mean()))

mse_test = cross_val_score(decision_tree_regressor, X_test, y_resposta_teste, scoring='neg_mean_squared_error', cv=5)
rmse_test = math.sqrt(abs(mse_test.mean()))

scores_treino = cross_val_score(decision_tree_regressor, X_train, y_resposta_treino, scoring='r2', cv=5)
scores_test = cross_val_score(decision_tree_regressor, X_test, y_resposta_teste, scoring='r2', cv=5)

print(' ')
print(' VALIDAÇÃO CRUZADA :')
print(' ')

print(' Métrica       treino             teste    ')
print(' -------  -----------------  ---------------')

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_treino , rmse_test ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   scores_treino.mean() ,   scores_test.mean() ) )
# Out:
#
#  ARVORE DE DECISÃO:
#
#
#  HOLDOUT:
#
#  Métrica        treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0000           0.0131
#       r2             1.0000           0.8730
#
#  VALIDAÇÃO CRUZADA :
#
#  Métrica       treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0182           0.0230
#       r2             0.6965           0.5959

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
#import math

# Create Decision Tree classifer object
random_forest_regressor = RandomForestRegressor()

# Train Decision Tree Classifer
random_forest_regressor = random_forest_regressor.fit(X_train,y_train.values.ravel())

#Predict the response for test dataset
y_resposta_treino = random_forest_regressor.predict(X_train)
y_resposta_teste = random_forest_regressor.predict(X_test)

print(' ')
print(' RANDOM FOREST:')
print(' ')
print(' ')
print(' HOLDOUT: ')
print(' ')

print(' Métrica        treino             teste    ')
print(' -------  -----------------  ---------------')

mse_in  = mean_squared_error(y_train,y_resposta_treino)
rmse_in = math.sqrt(mse_in)
r2_in   = r2_score(y_train,y_resposta_treino)

mse_out  = mean_squared_error(y_test,y_resposta_teste)
rmse_out = math.sqrt(mse_out)
r2_out   = r2_score(y_test,y_resposta_teste)

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_in , rmse_out ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   r2_in ,   r2_out ) )

from sklearn.model_selection import cross_val_score

mse_train = cross_val_score(random_forest_regressor, X_train, y_resposta_treino, scoring='neg_mean_squared_error', cv=5)
rmse_treino = math.sqrt(abs(mse_train.mean()))

mse_test = cross_val_score(random_forest_regressor, X_test, y_resposta_teste, scoring='neg_mean_squared_error', cv=5)
rmse_test = math.sqrt(abs(mse_test.mean()))

scores_treino = cross_val_score(random_forest_regressor, X_train, y_resposta_treino, scoring='r2', cv=5)
scores_test = cross_val_score(random_forest_regressor, X_test, y_resposta_teste, scoring='r2', cv=5)

print(' ')
print(' VALIDAÇÃO CRUZADA :')
print(' ')

print(' Métrica       treino             teste    ')
print(' -------  -----------------  ---------------')

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_treino , rmse_test ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   scores_treino.mean() ,   scores_test.mean() ) )
# Out:
#
#  RANDOM FOREST:
#
#
#  HOLDOUT:
#
#  Métrica        treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0046           0.0107
#       r2             0.9806           0.9157
#
#  VALIDAÇÃO CRUZADA :
#
#  Métrica       treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0083           0.0096
#       r2             0.9292           0.8979

# %% [markdown]
# ### Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics
#import math

# Create Decision Tree classifer object
gradient_boosting_regressor = GradientBoostingRegressor(random_state=0)

# Train Decision Tree Classifer
gradient_boosting_regressor = gradient_boosting_regressor.fit(X_train,y_train.values.ravel())

#Predict the response for test dataset
y_resposta_treino = gradient_boosting_regressor.predict(X_train)
y_resposta_teste = gradient_boosting_regressor.predict(X_test)

print(' ')
print(' GRADIENT BOOSTING:')
print(' ')
print(' ')
print(' HOLDOUT: ')
print(' ')

print(' Métrica        treino             teste    ')
print(' -------  -----------------  ---------------')

mse_in  = mean_squared_error(y_train,y_resposta_treino)
rmse_in = math.sqrt(mse_in)
r2_in   = r2_score(y_train,y_resposta_treino)

mse_out  = mean_squared_error(y_test,y_resposta_teste)
rmse_out = math.sqrt(mse_out)
r2_out   = r2_score(y_test,y_resposta_teste)

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_in , rmse_out ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   r2_in ,   r2_out ) )

from sklearn.model_selection import cross_val_score

mse_train = cross_val_score(gradient_boosting_regressor, X_train, y_resposta_treino, scoring='neg_mean_squared_error', cv=5)
rmse_treino = math.sqrt(abs(mse_train.mean()))

mse_test = cross_val_score(gradient_boosting_regressor, X_test, y_resposta_teste, scoring='neg_mean_squared_error', cv=5)
rmse_test = math.sqrt(abs(mse_test.mean()))

scores_treino = cross_val_score(gradient_boosting_regressor, X_train, y_resposta_treino, scoring='r2', cv=5)
scores_test = cross_val_score(gradient_boosting_regressor, X_test, y_resposta_teste, scoring='r2', cv=5)

print(' ')
print(' VALIDAÇÃO CRUZADA :')
print(' ')

print(' Métrica       treino             teste    ')
print(' -------  -----------------  ---------------')

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_treino , rmse_test ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   scores_treino.mean() ,   scores_test.mean() ) )
# Out:
#
#  GRADIENT BOOSTING:
#
#
#  HOLDOUT:
#
#  Métrica        treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0068           0.0095
#       r2             0.9573           0.9338
#
#  VALIDAÇÃO CRUZADA :
#
#  Métrica       treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0055           0.0082
#       r2             0.9700           0.9344

# %% [markdown]
# ### Support Vector Machines

# %%
from sklearn.svm import SVR
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
#import math

#param_grid = {'C': [0.1, 1, 10, 100, 1000], 'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 'kernel': ['rbf']}
#grid = GridSearchCV(SVR(), param_grid, refit=True, verbose=1, cv=10)
#grid.fit(X_train, y_train)

# Fit regression model
svr_rbf = SVR(kernel="rbf")
svr_lin = SVR(kernel="linear")
svr_poly = SVR(kernel="poly")

# Create Decision Tree classifer object
#clf = GradientBoostingRegressor(random_state=0)

# Train Decision Tree Classifer
svr_rbf = svr_rbf.fit(X_train,y_train.values.ravel())

#Predict the response for test dataset
y_resposta_treino = svr_rbf.predict(X_train)
y_resposta_teste = svr_rbf.predict(X_test)

print(' ')
print(' SUPPORT VECTOR MACHINES RBF KERNEL:')
print(' ')
print(' ')
print(' HOLDOUT: ')
print(' ')

print(' Métrica        treino             teste    ')
print(' -------  -----------------  ---------------')

mse_in  = mean_squared_error(y_train,y_resposta_treino)
rmse_in = math.sqrt(mse_in)
r2_in   = r2_score(y_train,y_resposta_treino)

mse_out  = mean_squared_error(y_test,y_resposta_teste)
rmse_out = math.sqrt(mse_out)
r2_out   = r2_score(y_test,y_resposta_teste)

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_in , rmse_out ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   r2_in ,   r2_out ) )

from sklearn.model_selection import cross_val_score

mse_train = cross_val_score(svr_rbf, X_train, y_resposta_treino, scoring='neg_mean_squared_error', cv=5)
rmse_treino = math.sqrt(abs(mse_train.mean()))

mse_test = cross_val_score(svr_rbf, X_test, y_resposta_teste, scoring='neg_mean_squared_error', cv=5)
rmse_test = math.sqrt(abs(mse_test.mean()))

scores_treino = cross_val_score(svr_rbf, X_train, y_resposta_treino, scoring='r2', cv=5)
scores_test = cross_val_score(svr_rbf, X_test, y_resposta_teste, scoring='r2', cv=5)

print(' ')
print(' VALIDAÇÃO CRUZADA :')
print(' ')

print(' Métrica       treino             teste    ')
print(' -------  -----------------  ---------------')

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_treino , rmse_test ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   scores_treino.mean() ,   scores_test.mean() ) )

#******************************************************************

# Train Decision Tree Classifer
svr_lin = svr_lin.fit(X_train,y_train.values.ravel())

#Predict the response for test dataset
y_resposta_treino = svr_lin.predict(X_train)
y_resposta_teste = svr_lin.predict(X_test)

print(' ')
print(' SUPPORT VECTOR MACHINES LINEAR KERNEL:')
print(' ')
print(' ')
print(' HOLDOUT: ')
print(' ')

print(' Métrica        treino             teste    ')
print(' -------  -----------------  ---------------')

mse_in  = mean_squared_error(y_train,y_resposta_treino)
rmse_in = math.sqrt(mse_in)
r2_in   = r2_score(y_train,y_resposta_treino)

mse_out  = mean_squared_error(y_test,y_resposta_teste)
rmse_out = math.sqrt(mse_out)
r2_out   = r2_score(y_test,y_resposta_teste)

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_in , rmse_out ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   r2_in ,   r2_out ) )

from sklearn.model_selection import cross_val_score

mse_train = cross_val_score(svr_lin, X_train, y_resposta_treino, scoring='neg_mean_squared_error', cv=5)
rmse_treino = math.sqrt(abs(mse_train.mean()))

mse_test = cross_val_score(svr_lin, X_test, y_resposta_teste, scoring='neg_mean_squared_error', cv=5)
rmse_test = math.sqrt(abs(mse_test.mean()))

scores_treino = cross_val_score(svr_lin, X_train, y_resposta_treino, scoring='r2', cv=5)
scores_test = cross_val_score(svr_lin, X_test, y_resposta_teste, scoring='r2', cv=5)

print(' ')
print(' VALIDAÇÃO CRUZADA :')
print(' ')

print(' Métrica       treino             teste    ')
print(' -------  -----------------  ---------------')

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_treino , rmse_test ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   scores_treino.mean() ,   scores_test.mean() ) )
#***************************************************************

# Train Decision Tree Classifer
svr_poly = svr_poly.fit(X_train,y_train.values.ravel())

#Predict the response for test dataset
y_resposta_treino = svr_poly.predict(X_train)
y_resposta_teste = svr_poly.predict(X_test)

print(' ')
print(' SUPPORT VECTOR MACHINES POLYNOMIAL KERNEL:')
print(' ')
print(' ')
print(' HOLDOUT: ')
print(' ')

print(' Métrica        treino             teste    ')
print(' -------  -----------------  ---------------')

mse_in  = mean_squared_error(y_train,y_resposta_treino)
rmse_in = math.sqrt(mse_in)
r2_in   = r2_score(y_train,y_resposta_treino)

mse_out  = mean_squared_error(y_test,y_resposta_teste)
rmse_out = math.sqrt(mse_out)
r2_out   = r2_score(y_test,y_resposta_teste)

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_in , rmse_out ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   r2_in ,   r2_out ) )
from sklearn.model_selection import cross_val_score

mse_train = cross_val_score(svr_poly, X_train, y_resposta_treino, scoring='neg_mean_squared_error', cv=5)
rmse_treino = math.sqrt(abs(mse_train.mean()))

mse_test = cross_val_score(svr_poly, X_test, y_resposta_teste, scoring='neg_mean_squared_error', cv=5)
rmse_test = math.sqrt(abs(mse_test.mean()))

scores_treino = cross_val_score(svr_poly, X_train, y_resposta_treino, scoring='r2', cv=5)
scores_test = cross_val_score(svr_poly, X_test, y_resposta_teste, scoring='r2', cv=5)

print(' ')
print(' VALIDAÇÃO CRUZADA :')
print(' ')

print(' Métrica       treino             teste    ')
print(' -------  -----------------  ---------------')

print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_treino , rmse_test ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   scores_treino.mean() ,   scores_test.mean() ) )
# Out:
#
#  SUPPORT VECTOR MACHINES RBF KERNEL:
#
#
#  HOLDOUT:
#
#  Métrica        treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0340           0.0358
#       r2            -0.0735           0.0500
#
#  VALIDAÇÃO CRUZADA :
#
#  Métrica       treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0112           0.0116
#       r2            -1.4296          -1.3709
#
#  SUPPORT VECTOR MACHINES LINEAR KERNEL:
#
#
#  HOLDOUT:
#
#  Métrica        treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0340           0.0358
#       r2            -0.0762           0.0489
#
#  VALIDAÇÃO CRUZADA :
#
#  Métrica       treino             teste
#  -------  -----------------  ---------------
#     rmse             0.0218           0.0117
#       r2            -8.2233          -1.4083
#
#  SUPPORT VECTOR MACHINES POLYNOMIAL KERNEL:
#
#
#  HOLDOUT:
#
# ...

# %%
rbf = SVC(kernel='rbf', C=1.0)

rbf.fit(X_train, y_train)

y_pred_rbf1 = rbf.predict(X_test)

print('Acurácia de SVM RBF e C=1.0: {0:0.4f}'.format(accuracy_score(y_test, y_pred_rbf1)))

# %% [markdown]
# ### Redes Neurais

# %%
from sklearn.model_selection import cross_validate, KFold

def validacao_cruzada(modelo):
  
  kf = KFold(n_splits=10)
  scores = cross_validate(modelo, X_train, y_train, cv=kf, scoring='r2', return_train_score=True)
  return scores


from sklearn.neural_network import MLPRegressor
#regr = MLPRegressor(random_state=64, max_iter=50000).fit(X_train, y_train.values.ravel())

regr = MLPRegressor(random_state=1234, solver='adam', activation='relu')

score1 = validacao_cruzada(regr)
#Predict the response for test dataset
y_resposta_treino = regr.predict(X_train)
y_resposta_teste = regr.predict(X_test)

print(' ')
print(' NEURAL NETWORK:')
print(' ')

print(' Métrica        treino             teste    ')
print(' -------  -----------------  ---------------')

mse_in  = mean_squared_error(y_train,y_resposta_treino)
rmse_in = math.sqrt(mse_in)
r2_in   = r2_score(y_train,y_resposta_treino)

mse_out  = mean_squared_error(y_test,y_resposta_teste)
rmse_out = math.sqrt(mse_out)
r2_out   = r2_score(y_test,y_resposta_teste)

print(' %7s  %17.4f  %15.4f' % (  'mse' ,  mse_in ,  mse_out ) )
print(' %7s  %17.4f  %15.4f' % ( 'rmse' , rmse_in , rmse_out ) )
print(' %7s  %17.4f  %15.4f' % (   'r2' ,   r2_in ,   r2_out ) )

# %%
# Redes Neurais
