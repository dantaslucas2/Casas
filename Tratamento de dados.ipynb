# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures,OneHotEncoder
from matplotlib import pyplot as plt
from category_encoders.one_hot import OrdinalEncoder
import category_encoders as ce
from sklearn.model_selection import train_test_split

# %%
newDataframe = pd.read_csv("train.csv")

newDataframe = newDataframe.drop(['Id'], axis=1)

#Tratando valores faltantes
newDataframe['Alley'] = newDataframe['Alley'].replace(np.nan, "None")
#MasVnrType
newDataframe['MasVnrType'] = newDataframe['MasVnrType'].replace(np.nan, "None")
#GarageType
newDataframe['GarageType'] = newDataframe['GarageType'].replace(np.nan, "None")
#MiscFeature
newDataframe['MiscFeature'] = newDataframe['MiscFeature'].replace(np.nan, "None")
#LotFrontage
newDataframe['LotFrontage'] = newDataframe['LotFrontage'].replace(np.nan, 0)
#MasVnrArea
newDataframe['MasVnrArea'] = newDataframe['MasVnrArea'].replace(np.nan, 0)
#GarageYrBlt - Mudar para data de construção da casa
newDataframe['GarageYrBlt'] = newDataframe['GarageYrBlt'].replace(np.nan, 0)

# %%
newDataframe
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave  None      Reg
# 1             20       RL         80.0     9600   Pave  None      Reg
# 2             60       RL         68.0    11250   Pave  None      IR1
# 3             70       RL         60.0     9550   Pave  None      IR1
# 4             60       RL         84.0    14260   Pave  None      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave  None      Reg
# 1456          20       RL         85.0    13175   Pave  None      Reg
# 1457          70       RL         66.0     9042   Pave  None      Reg
# 1458          20       RL         68.0     9717   Pave  None      Reg
# 1459          20       RL         75.0     9937   Pave  None      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
newDataframe[["SalePrice"]] = newDataframe[["SalePrice"]].apply(np.log)
newDataframe[["LotArea"]] = newDataframe[["LotArea"]].apply(np.log)

newDataframe
# Out:
#       MSSubClass MSZoning  LotFrontage   LotArea Street Alley LotShape  \
# 0             60       RL         65.0  9.041922   Pave  None      Reg
# 1             20       RL         80.0  9.169518   Pave  None      Reg
# 2             60       RL         68.0  9.328123   Pave  None      IR1
# 3             70       RL         60.0  9.164296   Pave  None      IR1
# 4             60       RL         84.0  9.565214   Pave  None      IR1
# ...          ...      ...          ...       ...    ...   ...      ...
# 1455          60       RL         62.0  8.976768   Pave  None      Reg
# 1456          20       RL         85.0  9.486076   Pave  None      Reg
# 1457          70       RL         66.0  9.109636   Pave  None      Reg
# 1458          20       RL         68.0  9.181632   Pave  None      Reg
# 1459          20       RL         75.0  9.204020   Pave  None      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
newDataframe.to_csv('data_mining.csv')

# %%
#np.isnan(newDataframe['MSSubClass'])
np.any(np.isnan(newDataframe['MSSubClass']))
# Out:
# False

# %%
#np.all(np.isfinite(newDataframe['']))

# %%
newDataframe.info(show_counts=False, verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   MSSubClass     int64
#  1   MSZoning       object
#  2   LotFrontage    float64
#  3   LotArea        float64
#  4   Street         object
#  5   Alley          object
#  6   LotShape       object
#  7   LandContour    object
#  8   Utilities      object
#  9   LotConfig      object
#  10  LandSlope      object
#  11  Neighborhood   object
#  12  Condition1     object
#  13  Condition2     object
#  14  BldgType       object
#  15  HouseStyle     object
#  16  OverallQual    int64
#  17  OverallCond    int64
#  18  YearBuilt      int64
#  19  YearRemodAdd   int64
#  20  RoofStyle      object
#  21  RoofMatl       object
#  22  Exterior1st    object
#  23  Exterior2nd    object
#  24  MasVnrType     object
#  25  MasVnrArea     float64
#  26  ExterQual      object
#  27  ExterCond      object
# ...

# %%
import seaborn as sns
